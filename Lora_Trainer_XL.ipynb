# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 🌟 XL Lora Trainer by Hollowstrawberry
#
# ❗ **Colab Premium is recommended.** Ideally you'd be changing the runtime to an A100 and use the maximum batch size.
# However you can still train for free if you load a diffusers model, it will just take much longer.
#
#
# This colab is based on the work of [Kohya-ss](https://github.com/kohya-ss/sd-scripts) and [Linaqruf](https://github.com/Linaqruf/kohya-trainer). Thank you!

# %% [markdown]
# ### ⭕ Disclaimer
# The purpose of this document is to research bleeding-edge technologies in the field of machine learning inference.
# Please read and follow the [Google Colab guidelines](https://research.google.com/colaboratory/faq.html) and its [Terms of Service](https://research.google.com/colaboratory/tos_v3.html).

# %% [markdown]
# | |GitHub|🇬🇧 English|🇪🇸 Spanish|
# |:--|:-:|:-:|:-:|
# | 🏠 **Homepage** | [![GitHub](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/github.svg)](https://github.com/hollowstrawberry/kohya-colab) | | |
# | 📊 **Dataset Maker** | [![GitHub](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/github.svg)](https://github.com/hollowstrawberry/kohya-colab/blob/main/Dataset_Maker.ipynb) | [![Open in Colab](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/colab-badge.svg)](https://colab.research.google.com/github/hollowstrawberry/kohya-colab/blob/main/Dataset_Maker.ipynb) | [![Abrir en Colab](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/colab-badge-spanish.svg)](https://colab.research.google.com/github/hollowstrawberry/kohya-colab/blob/main/Spanish_Dataset_Maker.ipynb) |
# | ⭐ **Lora Trainer** | [![GitHub](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/github.svg)](https://github.com/hollowstrawberry/kohya-colab/blob/main/Lora_Trainer.ipynb) | [![Open in Colab](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/colab-badge.svg)](https://colab.research.google.com/github/hollowstrawberry/kohya-colab/blob/main/Lora_Trainer.ipynb) | [![Abrir en Colab](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/colab-badge-spanish.svg)](https://colab.research.google.com/github/hollowstrawberry/kohya-colab/blob/main/Spanish_Lora_Trainer.ipynb) |
# | 🌟 **XL Lora Trainer** | [![GitHub](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/github.svg)](https://github.com/hollowstrawberry/kohya-colab/blob/main/Lora_Trainer_XL.ipynb) | [![Open in Colab](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/colab-badge.svg)](https://colab.research.google.com/github/hollowstrawberry/kohya-colab/blob/main/Lora_Trainer_XL.ipynb) |  |

# %%
import os
import re
import toml
import pathlib
from time import time
from IPython.display import Markdown, display

# These carry information from past executions
if "model_url" in globals():
  old_model_url = model_url
else:
  old_model_url = None
if "dependencies_installed" not in globals():
  dependencies_installed = False
if "model_file" not in globals():
  model_file = None

# These may be set by other cells, some are legacy
if "custom_dataset" not in globals():
  custom_dataset = None
if "override_dataset_config_file" not in globals():
  override_dataset_config_file = None
if "continue_from_lora" not in globals():
  continue_from_lora = ""
if "override_config_file" not in globals():
  override_config_file = None

COLAB = True
SOURCE = "https://github.com/qaneel/kohya-trainer"
COMMIT = None
BETTER_EPOCH_NAMES = True
LOAD_TRUNCATED_IMAGES = True
try:
  LOWRAM = int(next(line.split()[1] for line in open('/proc/meminfo') if "MemTotal" in line)) / (1024**2) < 15
except:
  LOWRAM = False

#@title ## 🚩 Start Here

#@markdown ### ▶️ Setup
#@markdown Your project name will be the same as the folder containing your images. Spaces aren't allowed.
project_name = "Realystic_Model" #@param {type:"string"}
project_name = project_name.strip()
#@markdown The folder structure doesn't matter and is purely for comfort. Make sure to always pick the same one. I like organizing by project.
folder_structure = "Organize by project (MyDrive/Loras/project_name/dataset)" #@param ["Organize by category (MyDrive/lora_training/datasets/project_name)", "Organize by project (MyDrive/Loras/project_name/dataset)"]
#@markdown Decide the model that will be downloaded and used for training. You can also choose your own by pasting its download link, or a file in your Google Drive starting with `/content/drive/MyDrive`.
training_model = "Pony Diffusion V6 XL" #@param ["Pony Diffusion V6 XL", "Illustrious XL 0.1", "Animagine XL V3", "Stable Diffusion XL 1.0 base"]
optional_custom_training_model = "" #@param {type:"string"}
#@markdown Using a diffusers model utilizes less resources. The 3 options above will work with or without diffusers.
load_diffusers = True #@param {type:"boolean"}
#@markdown Use wandb if you want to visualize the progress of your training over time.
wandb_key = "" #@param {type:"string"}

if optional_custom_training_model:
  model_url = optional_custom_training_model
elif "Pony" in training_model:
  if load_diffusers:
    model_url = "https://huggingface.co/hollowstrawberry/67AB2F"
  else:
    model_url = "https://civitai.com/api/download/models/290640"
  model_file = "/content/ponyDiffusionV6XL.safetensors"
elif "Animagine" in training_model:
  if load_diffusers:
    model_url = "https://huggingface.co/cagliostrolab/animagine-xl-3.0"
  else:
    model_url = "https://civitai.com/api/download/models/293564"
  model_file = "/content/animagineXLV3.safetensors"
elif "Illustrious" in training_model:
  if load_diffusers:
    model_url = "https://huggingface.co/OnomaAIResearch/Illustrious-xl-early-release-v0"
  else:
    model_url = "https://huggingface.co/OnomaAIResearch/Illustrious-xl-early-release-v0/resolve/main/Illustrious-XL-v0.1.safetensors"
else:
  if load_diffusers:
    model_url = "https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/"
  else:
    model_url = "https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_base_1.0.safetensors"

if load_diffusers:
  vae_file= "stabilityai/sdxl-vae"
else:
  vae_url = "https://huggingface.co/stabilityai/sdxl-vae/resolve/main/sdxl_vae.safetensors"
  vae_file = "/content/sdxl_vae.safetensors"

model_url = model_url.strip()

#@markdown ### ▶️ Processing
resolution = 1024 #param {type:"slider", min:768, max:1536, step:128}
caption_extension = ".txt" #@param [".txt", ".caption"]
#@markdown Shuffling anime tags in place improves learning and prompting. An activation tag goes at the start of every text file and will not be shuffled.<p>
shuffle_tags = True #@param {type:"boolean"}
shuffle_caption = shuffle_tags
activation_tags = "1" #@param [0,1,2,3]
keep_tokens = int(activation_tags)

#@markdown ### ▶️ Steps <p>
#@markdown Your images will repeat this number of times during training. I recommend that your images multiplied by their repeats is between 200 and 400.
num_repeats = 300 #@param {type:"number"}
#@markdown Choose how long you want to train for. A good starting point is around 10 epochs or around 2000 steps.<p>
#@markdown One epoch is a number of steps equal to: your number of images multiplied by their repeats, divided by batch size. <p>
preferred_unit = "Steps" #@param ["Epochs", "Steps"]
how_many = 2000 #@param {type:"number"}
max_train_epochs = how_many if preferred_unit == "Epochs" else None
max_train_steps = how_many if preferred_unit == "Steps" else None
#@markdown Saving more epochs will let you compare your Lora's progress better.
save_every_n_epochs = 1 #@param {type:"number"}
keep_only_last_n_epochs = 10 #@param {type:"number"}
if not save_every_n_epochs:
  save_every_n_epochs = max_train_epochs
if not keep_only_last_n_epochs:
  keep_only_last_n_epochs = max_train_epochs

#@markdown ### ▶️ Learning
#@markdown The learning rate is the most important for your results. If your Lora produces black images, lower the unet and text encoder to 1e-4 and 1e-5 respectively, or even lower. <p>
#@markdown If you're training a style you can choose to set the text encoder to 0.
unet_lr = 3e-4 #@param {type:"number"}
text_encoder_lr = 6e-5 #@param {type:"number"}
#@markdown The scheduler is the algorithm that guides the learning rate. If you're not sure, pick `constant` and ignore the number. I personally recommend `cosine_with_restarts` with 3 restarts.
lr_scheduler = "cosine_with_restarts" #@param ["constant", "cosine", "cosine_with_restarts", "constant_with_warmup", "linear", "polynomial"]
lr_scheduler_number = 3 #@param {type:"number"}
#@markdown Steps spent "warming up" the learning rate during training for efficiency. I recommend leaving it at 5%.
lr_warmup_ratio = 0.05 #@param {type:"slider", min:0.0, max:0.2, step:0.01}
lr_warmup_steps = 0
#@markdown Adjusts loss over time, makes learning much more efficient. The paper recommends 5.0, I recommend 8.0 for anime. Higher value makes it less strict. Set to 0 to disable.
min_snr_gamma = 8.0 #@param {type:"slider", min:0.0, max:16.0, step:0.5}
#@markdown Multinoise may help with color balance (darker darks, lighter lights).
multinoise = True #@param {type:"boolean"}

#@markdown ### ▶️ Structure
#@markdown LoRA is the classic type and good for a variety of purposes. LoCon is good with artstyles as it has more layers to learn more aspects of the dataset.
lora_type = "LoRA" #@param ["LoRA", "LoCon"]

#@markdown Below are some recommended XL values for the following settings:

#@markdown | type | network_dim | network_alpha | conv_dim | conv_alpha |
#@markdown | :---: | :---: | :---: | :---: | :---: |
#@markdown | Regular LoRA | 8 | 4 |   |   |
#@markdown | Style LoCon | 16 | 8 | 16 | 8 |

#@markdown More dim means larger Lora, it can hold more information but more isn't always better.
network_dim = 32 #@param {type:"slider", min:1, max:32, step:1}
network_alpha = 32 #@param {type:"slider", min:1, max:32, step:1}
#@markdown The following two values only apply to the additional layers of LoCon.
conv_dim = 4 #@param {type:"slider", min:1, max:32, step:1}
conv_alpha = 1 #@param {type:"slider", min:1, max:32, step:1}

network_module = "networks.lora"
network_args = None
if lora_type.lower() == "locon":
  network_args = [f"conv_dim={conv_dim}", f"conv_alpha={conv_alpha}"]

#@markdown ### ▶️ Training
#@markdown Adjust these parameters depending on your colab configuration.
#@markdown If you're using the free tier you should select a diffusers model at the top of this cell.
#@markdown
#@markdown Higher batch size is often faster but uses more memory.
train_batch_size = 4 #@param {type:"slider", min:1, max:16, step:1}
#@markdown I have found no substantial difference between sdpa and xformers.
cross_attention = "sdpa" #@param ["sdpa", "xformers"]
#@markdown If you're on an A100 you should enable bf16.
mixed_precision = "fp16" #@param ["bf16", "fp16"]
#@markdown Caching latents to drive will add a 250KB file next to each image but will use considerably less memory.
cache_latents = True #@param {type:"boolean"}
cache_latents_to_drive = True #@param {type:"boolean"}
#@markdown The following option will turn off shuffle_tags and disable text encoder training.
cache_text_encoder_outputs  = False  # @param {type:"boolean"}

#@markdown ### ▶️ Advanced
#@markdown The optimizer is the algorithm used for training. AdanW8Bit is the default and works great, while Prodigy manages learning rate automatically and may have several advantages such as training faster due to needing less steps as well as working better for small datasets.
optimizer = "AdamW8bit" #@param ["AdamW8bit", "Prodigy", "DAdaptation", "DadaptAdam", "DadaptLion", "AdamW", "Lion", "SGDNesterov", "SGDNesterov8bit", "AdaFactor"]
#@markdown Recommended args for AdamW8bit: `weight_decay=0.1 betas=[0.9,0.99]`<p>
#@markdown Recommended args for Prodigy: `decouple=True weight_decay=0.01 betas=[0.9,0.999] d_coef=2 use_bias_correction=True safeguard_warmup=True`<p>
#markdown Recommended args for CAME: `weight_decay=0.04`
optimizer_args = "weight_decay=0.1 betas=[0.9,0.99]" #@param {type:"string"}
optimizer_args = [a.strip() for a in optimizer_args.split(' ') if a]
#@markdown If Dadapt or Prodigy are selected and the recommended box is checked, the following recommended values will override any previous settings:<p>
#@markdown `unet_lr=0.75`, `text_encoder_lr=0.75`, `network_alpha=network_dim`<p>
#markdown If CAME + REX is selected and the recommended box is checked, the following recommended values will override any previous settings:<p>
#markdown `unet_lr=1e-4`, `text_encoder_lr=1e-6, betas=default_came_betas`
recommended_values = True #@param {type:"boolean"}

if any(opt in optimizer.lower() for opt in ["dadapt", "prodigy"]):
  if recommended_values:
    unet_lr = 0.75
    text_encoder_lr = 0.75
    network_alpha = network_dim
elif "CAME" in optimizer:
  optimizer = "CAME"
  lr_scheduler = "REX"
  if recommended_values:
    unet_lr = 1e-4
    text_encoder_lr = 1e-6
    for i in range(len(optimizer_args)):
      if "betas" in optimizer_args[i]:
        optimizer_args.pop(i)
        break

lr_scheduler_num_cycles = lr_scheduler_number if lr_scheduler == "cosine_with_restarts" else 0
lr_scheduler_power = lr_scheduler_number if lr_scheduler == "polynomial" else 0


#@markdown ### ▶️ Ready
#@markdown You can now run this cell to cook your Lora. Good luck! <p>


# 👩‍💻 Cool code goes here

root_dir = "/content" if COLAB else pathlib.Path.home() / "Loras"
deps_dir = os.path.join(root_dir, "deps")
repo_dir = os.path.join(root_dir, "kohya-trainer")

if "/Loras" in folder_structure:
  main_dir      = os.path.join(root_dir, "drive/MyDrive/Loras") if COLAB else root_dir
  log_folder    = os.path.join(main_dir, "_logs")
  config_folder = os.path.join(main_dir, project_name)
  images_folder = os.path.join(main_dir, project_name, "dataset")
  output_folder = os.path.join(main_dir, project_name, "output")
else:
  main_dir      = os.path.join(root_dir, "drive/MyDrive/lora_training") if COLAB else root_dir
  images_folder = os.path.join(main_dir, "datasets", project_name)
  output_folder = os.path.join(main_dir, "output", project_name)
  config_folder = os.path.join(main_dir, "config", project_name)
  log_folder    = os.path.join(main_dir, "log")

config_file = os.path.join(config_folder, "training_config.toml")
dataset_config_file = os.path.join(config_folder, "dataset_config.toml")
accelerate_config_file = os.path.join(repo_dir, "accelerate_config/config.yaml")

def install_dependencies():
  os.chdir(root_dir)
  # !git clone {SOURCE} {repo_dir}
  os.chdir(repo_dir)
  if COMMIT:
    # !git reset --hard {COMMIT}
  # !wget https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/train_network_xl_wrapper.py -q -O train_network_xl_wrapper.py
  # !wget https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/dracula.py -q -O dracula.py

  # !apt -y update -qq
  # !apt -y install aria2 -qq
  # !pip install torch==2.5.1+cu121 accelerate==0.19.0 transformers==4.30.2 diffusers==0.18.2 \
    bitsandbytes==0.40.0.post4 opencv-python jax==0.4.23 jaxlib==0.4.23 \
    pytorch-lightning==1.9.0 voluptuous==0.13.1 toml==0.10.2 ftfy==6.1.1 einops==0.6.0 \
    safetensors pygments huggingface-hub==0.22.0 wandb invisible-watermark==0.2.0 open-clip-torch==2.20.0 \
    dadaptation==3.1 prodigyopt==1.0 lion-pytorch==0.1.2
  # !pip install -e .
  if cross_attention == "xformers":
    # !pip install -q xformers==0.0.26.dev778
  if "CAME" in optimizer:
    # !pip install came-pytorch
    # !wget https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/train_util.py -q -O library/train_util.py

  # patch kohya for minor stuff
  if LOWRAM:
    # !sed -i "s@cpu@cuda@" library/model_util.py
  if LOAD_TRUNCATED_IMAGES:
    # !sed -i 's/from PIL import Image/from PIL import Image, ImageFile\nImageFile.LOAD_TRUNCATED_IMAGES=True/g' library/train_util.py # fix truncated jpegs error
  if BETTER_EPOCH_NAMES:
    # !sed -i 's/{:06d}/{:02d}/g' library/train_util.py # make epoch names shorter
    # !sed -i 's/"." + args.save_model_as)/"-{:02d}.".format(num_train_epochs) + args.save_model_as)/g' train_network.py # name of the last epoch will match the rest

  from accelerate.utils import write_basic_config
  if not os.path.exists(accelerate_config_file):
    write_basic_config(save_location=accelerate_config_file)

  os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
  os.environ["BITSANDBYTES_NOWELCOME"] = "1"
  os.environ["SAFETENSORS_FAST_GPU"] = "1"

def validate_dataset():
  global lr_warmup_steps, lr_warmup_ratio, caption_extension, keep_tokens, model_url
  supported_types = (".png", ".jpg", ".jpeg", ".webp", ".bmp")

  if model_url.startswith("/content/drive/") and not os.path.exists(model_url):
    print("💥 Error: The custom training model you specified was not found in your Google Drive.")
    return

  print("\n💿 Checking dataset...")
  if not project_name.strip() or any(c in project_name for c in " .()\"'\\/"):
    print("💥 Error: Please choose a valid project name.")
    return

  # Find the folders and files
  if custom_dataset:
    try:
      datconf = toml.loads(custom_dataset)
      datasets = [d for d in datconf["datasets"][0]["subsets"]]
    except:
      print(f"💥 Error: Your custom dataset is invalid or contains an error! Please check the original template.")
      return
    reg = [d.get("image_dir") for d in datasets if d.get("is_reg", False)]
    datasets_dict = {d["image_dir"]: d["num_repeats"] for d in datasets}
    folders = datasets_dict.keys()
    files = [f for folder in folders for f in os.listdir(folder)]
    images_repeats = {folder: (len([f for f in os.listdir(folder) if f.lower().endswith(supported_types)]), datasets_dict[folder]) for folder in folders}
  else:
    reg = []
    folders = [images_folder]
    files = os.listdir(images_folder)
    images_repeats = {images_folder: (len([f for f in files if f.lower().endswith(supported_types)]), num_repeats)}

  # Validation
  for folder in folders:
    if not os.path.exists(folder):
      print(f"💥 Error: The folder {folder.replace('/content/drive/', '')} doesn't exist.")
      return
  for folder, (img, rep) in images_repeats.items():
    if not img:
      print(f"💥 Error: Your {folder.replace('/content/drive/', '')} folder is empty.")
      return
  test_files = []
  for f in files:
    if not f.lower().endswith((caption_extension, ".npz")) and not f.lower().endswith(supported_types):
      print(f"💥 Error: Invalid file in dataset: \"{f}\". Aborting.")
      return
    for ff in test_files:
      if f.endswith(supported_types) and ff.endswith(supported_types) \
          and os.path.splitext(f)[0] == os.path.splitext(ff)[0]:
        print(f"💥 Error: The files {f} and {ff} cannot have the same name. Aborting.")
        return
    test_files.append(f)

  if caption_extension and not [txt for txt in files if txt.lower().endswith(caption_extension)]:
    caption_extension = ""
  if continue_from_lora and not (continue_from_lora.endswith(".safetensors") and os.path.exists(continue_from_lora)):
    print(f"💥 Error: Invalid path to existing Lora. Example: /content/drive/MyDrive/Loras/example.safetensors")
    return

  # Pretty stuff

  pre_steps_per_epoch = sum(img*rep for (img, rep) in images_repeats.values())
  steps_per_epoch = pre_steps_per_epoch/train_batch_size
  total_steps = max_train_steps or int(max_train_epochs*steps_per_epoch)
  estimated_epochs = int(total_steps/steps_per_epoch)
  lr_warmup_steps = int(total_steps*lr_warmup_ratio)

  for folder, (img, rep) in images_repeats.items():
    print("📁"+folder.replace("/content/drive/", "") + (" (Regularization)" if folder in reg else ""))
    print(f"📈 Found {img} images with {rep} repeats, equaling {img*rep} steps.")
  print(f"📉 Divide {pre_steps_per_epoch} steps by {train_batch_size} batch size to get {steps_per_epoch} steps per epoch.")
  if max_train_epochs:
    print(f"🔮 There will be {max_train_epochs} epochs, for around {total_steps} total training steps.")
  else:
    print(f"🔮 There will be {total_steps} steps, divided into {estimated_epochs} epochs and then some.")

  if total_steps > 10000:
    print("💥 Error: Your total steps are too high. You probably made a mistake. Aborting...")
    return

  return True

def create_config():
  global dataset_config_file, config_file, model_file

  if override_config_file:
    config_file = override_config_file
    print(f"\n⭕ Using custom config file {config_file}")
  else:
    config_dict = {
      "network_arguments": {
        "unet_lr": unet_lr,
        "text_encoder_lr": text_encoder_lr if not cache_text_encoder_outputs else 0,
        "network_dim": network_dim,
        "network_alpha": network_alpha,
        "network_module": network_module,
        "network_args": network_args,
        "network_train_unet_only": text_encoder_lr == 0 or cache_text_encoder_outputs,
        "network_weights": continue_from_lora if continue_from_lora else None
      },
      "optimizer_arguments": {
        "learning_rate": unet_lr,
        "lr_scheduler": lr_scheduler,
        "lr_scheduler_num_cycles": lr_scheduler_num_cycles if lr_scheduler == "cosine_with_restarts" else None,
        "lr_scheduler_power": lr_scheduler_power if lr_scheduler == "polynomial" else None,
        "lr_warmup_steps": lr_warmup_steps if lr_scheduler != "constant" else None,
        "optimizer_type": optimizer,
        "optimizer_args": optimizer_args if optimizer_args else None,
      },
      "training_arguments": {
        "pretrained_model_name_or_path": model_file,
        "vae": vae_file,
        "max_train_steps": max_train_steps,
        "max_train_epochs": max_train_epochs,
        "train_batch_size": train_batch_size,
        "seed": 42,
        "max_token_length": 225,
        "xformers": cross_attention == "xformers",
        "sdpa": cross_attention == "sdpa",
        "min_snr_gamma": min_snr_gamma if min_snr_gamma > 0 else None,
        "lowram": LOWRAM,
        "no_half_vae": True,
        "gradient_checkpointing": True,
        "gradient_accumulation_steps": 1,
        "max_data_loader_n_workers": 8,
        "persistent_data_loader_workers": True,
        "mixed_precision": mixed_precision,
        "full_bf16": mixed_precision == "bf16",
        "cache_latents": cache_latents,
        "cache_latents_to_disk": cache_latents_to_drive,
        "cache_text_encoder_outputs": cache_text_encoder_outputs,
        "min_timestep": 0,
        "max_timestep": 1000,
        "prior_loss_weight": 1.0,
        "multires_noise_iterations": 6 if multinoise else None,
        "multires_noise_discount": 0.3 if multinoise else None,
      },
      "saving_arguments": {
        "save_precision": "fp16",
        "save_model_as": "safetensors",
        "save_every_n_epochs": save_every_n_epochs,
        "save_last_n_epochs": keep_only_last_n_epochs,
        "output_name": project_name,
        "output_dir": output_folder,
        "log_prefix": project_name,
        "logging_dir": log_folder,
        "wandb_api_key": wandb_key if wandb_key else None,
        "log_with": "wandb" if wandb_key else None,
      }
    }

    for key in config_dict:
      if isinstance(config_dict[key], dict):
        config_dict[key] = {k: v for k, v in config_dict[key].items() if v is not None}

    with open(config_file, "w") as f:
      f.write(toml.dumps(config_dict))
    print(f"\n📄 Config saved to {config_file}")

  if override_dataset_config_file:
    dataset_config_file = override_dataset_config_file
    print(f"⭕ Using custom dataset config file {dataset_config_file}")
  else:
    dataset_config_dict = {
      "general": {
        "resolution": resolution,
        "shuffle_caption": shuffle_caption and not cache_text_encoder_outputs,
        "keep_tokens": keep_tokens,
        "flip_aug": False,
        "caption_extension": caption_extension,
        "enable_bucket": True,
        "bucket_no_upscale": False,
        "bucket_reso_steps": 64,
        "min_bucket_reso": 256,
        "max_bucket_reso": 4096,
      },
      "datasets": toml.loads(custom_dataset)["datasets"] if custom_dataset else [
        {
          "subsets": [
            {
              "num_repeats": num_repeats,
              "image_dir": images_folder,
              "class_tokens": None if caption_extension else project_name
            }
          ]
        }
      ]
    }

    for key in dataset_config_dict:
      if isinstance(dataset_config_dict[key], dict):
        dataset_config_dict[key] = {k: v for k, v in dataset_config_dict[key].items() if v is not None}

    with open(dataset_config_file, "w") as f:
      f.write(toml.dumps(dataset_config_dict))
    print(f"📄 Dataset config saved to {dataset_config_file}")

def download_model():
  global old_model_url, model_url, model_file, vae_url, vae_file
  real_model_url = model_url  # There was a reason for having a separate variable but I forgot what it was.

  if real_model_url.startswith("/content/drive/"):
    # Local model, already checked to exist
    model_file = real_model_url
    print(f"📁 Using local model file: {model_file}")
    # Validation
    if model_file.lower().endswith(".safetensors"):
      from safetensors.torch import load_file as load_safetensors
      try:
        test = load_safetensors(model_file)
        del test
      except:
        return False
    elif model_file.lower().endswith(".ckpt"):
      from torch import load as load_ckpt
      try:
        test = load_ckpt(model_file)
        del test
      except:
        return False
    return True

  else:
    # Downloadable model
    if load_diffusers:
      if 'huggingface.co' in real_model_url:
          match = re.search(r'huggingface\.co/([^/]+)/([^/]+)', real_model_url)
          if match:
              username = match.group(1)
              model_name = match.group(2)
              model_file = f"{username}/{model_name}"
              from huggingface_hub import HfFileSystem
              fs = HfFileSystem()
              existing_folders = set(fs.ls(model_file, detail=False))
              necessary_folders = [ "scheduler", "text_encoder", "text_encoder_2", "tokenizer", "tokenizer_2", "unet", "vae" ]
              if all(f"{model_file}/{folder}" in existing_folders for folder in necessary_folders):
                print("🍃 Diffusers model identified.")  # Will be handled by kohya
                return True
      raise ValueError("💥 Failed to load Diffusers model. If this model is not Diffusers, have you tried turning it off at the top of the colab?")

    # Define local filename
    if not model_file:
      if real_model_url.lower().endswith((".ckpt", ".safetensors")):
        model_file = f"/content{real_model_url[real_model_url.rfind('/'):]}"
      else:
        model_file = "/content/downloaded_model.safetensors"
        if os.path.exists(model_file):
          # !rm "{model_file}"

    # HuggingFace
    if m := re.search(r"(?:https?://)?(?:www\.)?huggingface\.co/[^/]+/[^/]+/blob", real_model_url):
      real_model_url = real_model_url.replace("blob", "resolve")
    # Civitai
    elif m := re.search(r"(?:https?://)?(?:www\\.)?civitai\.com/models/([0-9]+)(/[A-Za-z0-9-_]+)?", real_model_url):
      if m.group(2):
        model_file = f"/content{m.group(2)}.safetensors"
      if m := re.search(r"modelVersionId=([0-9]+)", real_model_url):
        real_model_url = f"https://civitai.com/api/download/models/{m.group(1)}"
      else:
        raise ValueError("💥 optional_custom_training_model contains a civitai link, but the link doesn't include a modelVersionId. You can also right click the download button to copy the direct download link.")

    # Download checkpoint
    # !aria2c "{real_model_url}" --console-log-level=warn -c -s 16 -x 16 -k 10M -d / -o "{model_file}"

    # Download VAE
    if not os.path.exists(vae_file):
      # !aria2c "{vae_url}" --console-log-level=warn -c -s 16 -x 16 -k 10M -d / -o "{vae_file}"

    # Validation

    if model_file.lower().endswith(".safetensors"):
      from safetensors.torch import load_file as load_safetensors
      try:
        test = load_safetensors(model_file)
        del test
      except:
        new_model_file = os.path.splitext(model_file)[0]+".ckpt"
        # !mv "{model_file}" "{new_model_file}"
        model_file = new_model_file
        print(f"Renamed model to {os.path.splitext(model_file)[0]}.ckpt")

    if model_file.lower().endswith(".ckpt"):
      from torch import load as load_ckpt
      try:
        test = load_ckpt(model_file)
        del test
      except:
        return False

  return True

def main():
  global dependencies_installed

  if COLAB and not os.path.exists('/content/drive'):
    from google.colab import drive
    print("📂 Connecting to Google Drive...")
    drive.mount('/content/drive')

  for dir in (main_dir, deps_dir, repo_dir, log_folder, images_folder, output_folder, config_folder):
    os.makedirs(dir, exist_ok=True)

  if not validate_dataset():
    return

  if not dependencies_installed:
    print("\n🏭 Installing dependencies...\n")
    t0 = time()
    install_dependencies()
    t1 = time()
    dependencies_installed = True
    print(f"\n✅ Installation finished in {int(t1-t0)} seconds.")
  else:
    print("\n✅ Dependencies already installed.")

  if old_model_url != model_url or not model_file or not os.path.exists(model_file):
    print("\n🔄 Getting model...")
    if not download_model():
      print("\n💥 Error: The model you specified is invalid or corrupted."
            "\nIf you're using an URL, please check that the model is accessible without being logged in."
            "\nYou can try civitai or huggingface URLs, or a path in your Google Drive starting with /content/drive/MyDrive")
      return
    print()
  else:
    print("\n🔄 Model already downloaded.\n")

  create_config()

  print("\n⭐ Starting trainer...\n")
  os.chdir(repo_dir)

  # !accelerate launch --quiet --config_file={accelerate_config_file} --num_cpu_threads_per_process=1 train_network_xl_wrapper.py --dataset_config={dataset_config_file} --config_file={config_file}

  if not get_ipython().__dict__['user_ns']['_exit_code']:
    display(Markdown("### ✅ Done! [Go download your Lora from Google Drive](https://drive.google.com/drive/my-drive)\n"
                     "### There will be several files, you should try the latest version (the file with the largest number next to it)"))

main()
# Out:
# 💿 Checking dataset...
# 📁MyDrive/Loras/Realystic_Model/dataset
# 📈 Found 298 images with 300 repeats, equaling 89400 steps.
# 📉 Divide 89400 steps by 4 batch size to get 22350.0 steps per epoch.
# 🔮 There will be 2000 steps, divided into 0 epochs and then some.
#
# 🏭 Installing dependencies...
#
# Cloning into '/content/kohya-trainer'...
# remote: Enumerating objects: 2441, done.
# remote: Counting objects: 100% (1000/1000), done.
# remote: Compressing objects: 100% (224/224), done.
# remote: Total 2441 (delta 873), reused 776 (delta 776), pack-reused 1441 (from 1)
# Receiving objects: 100% (2441/2441), 4.19 MiB | 15.89 MiB/s, done.
# Resolving deltas: 100% (1638/1638), done.
# 54 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# The following additional packages will be installed:
#   libaria2-0 libc-ares2
# The following NEW packages will be installed:
#   aria2 libaria2-0 libc-ares2
# 0 upgraded, 3 newly installed, 0 to remove and 54 not upgraded.
# Need to get 1,513 kB of archives.
# After this operation, 5,441 kB of additional disk space will be used.
# Selecting previously unselected package libc-ares2:amd64.
# (Reading database ... 123634 files and directories currently installed.)
# Preparing to unpack .../libc-ares2_1.18.1-1ubuntu0.22.04.3_amd64.deb ...
# Unpacking libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.3) ...
# Selecting previously unselected package libaria2-0:amd64.
# Preparing to unpack .../libaria2-0_1.36.0-1_amd64.deb ...
# Unpacking libaria2-0:amd64 (1.36.0-1) ...
# Selecting previously unselected package aria2.
# Preparing to unpack .../aria2_1.36.0-1_amd64.deb ...
# Unpacking aria2 (1.36.0-1) ...
# Setting up libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.3) ...
# Setting up libaria2-0:amd64 (1.36.0-1) ...
# Setting up aria2 (1.36.0-1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# Requirement already satisfied: torch==2.5.1+cu121 in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Collecting accelerate==0.19.0
#   Downloading accelerate-0.19.0-py3-none-any.whl.metadata (16 kB)
# Collecting transformers==4.30.2
#   Downloading transformers-4.30.2-py3-none-any.whl.metadata (113 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.6/113.6 kB 5.7 MB/s eta 0:00:00
# Collecting diffusers==0.18.2
#   Downloading diffusers-0.18.2-py3-none-any.whl.metadata (17 kB)
# Collecting bitsandbytes==0.40.0.post4
#   Downloading bitsandbytes-0.40.0.post4-py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.10.0.84)
# Collecting jax==0.4.23
#   Downloading jax-0.4.23-py3-none-any.whl.metadata (24 kB)
# Collecting jaxlib==0.4.23
#   Downloading jaxlib-0.4.23-cp310-cp310-manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting pytorch-lightning==1.9.0
#   Downloading pytorch_lightning-1.9.0-py3-none-any.whl.metadata (23 kB)
# Collecting voluptuous==0.13.1
#   Downloading voluptuous-0.13.1-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: toml==0.10.2 in /usr/local/lib/python3.10/dist-packages (0.10.2)
# Collecting ftfy==6.1.1
#   Downloading ftfy-6.1.1-py3-none-any.whl.metadata (6.1 kB)
# Collecting einops==0.6.0
#   Downloading einops-0.6.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (0.4.5)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (2.18.0)
# Collecting huggingface-hub==0.22.0
#   Downloading huggingface_hub-0.22.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: wandb in /usr/local/lib/python3.10/dist-packages (0.19.1)
# Collecting invisible-watermark==0.2.0
#   Downloading invisible_watermark-0.2.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting open-clip-torch==2.20.0
#   Downloading open_clip_torch-2.20.0-py3-none-any.whl.metadata (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 2.2 MB/s eta 0:00:00
# Collecting dadaptation==3.1
#   Downloading dadaptation-3.1.tar.gz (13 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting prodigyopt==1.0
#   Downloading prodigyopt-1.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting lion-pytorch==0.1.2
#   Downloading lion_pytorch-0.1.2-py3-none-any.whl.metadata (620 bytes)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1+cu121) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1+cu121) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1+cu121) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1+cu121) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1+cu121) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1+cu121) (1.13.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.19.0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.19.0) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate==0.19.0) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate==0.19.0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2) (2.32.3)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers==4.30.2)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2) (4.67.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from diffusers==0.18.2) (11.0.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from diffusers==0.18.2) (8.5.0)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax==0.4.23) (0.4.1)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax==0.4.23) (3.4.0)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.10/dist-packages (from jax==0.4.23) (1.13.1)
# Collecting torchmetrics>=0.7.0 (from pytorch-lightning==1.9.0)
#   Downloading torchmetrics-1.6.1-py3-none-any.whl.metadata (21 kB)
# Collecting lightning-utilities>=0.4.2 (from pytorch-lightning==1.9.0)
#   Downloading lightning_utilities-0.11.9-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.10/dist-packages (from ftfy==6.1.1) (0.2.13)
# Collecting PyWavelets>=1.1.1 (from invisible-watermark==0.2.0)
#   Downloading pywavelets-1.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from open-clip-torch==2.20.0) (0.20.1+cu121)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from open-clip-torch==2.20.0) (0.2.0)
# Collecting protobuf<4 (from open-clip-torch==2.20.0)
#   Downloading protobuf-3.20.3-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (679 bytes)
# Requirement already satisfied: timm in /usr/local/lib/python3.10/dist-packages (from open-clip-torch==2.20.0) (1.0.12)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch==2.5.1+cu121) (1.3.0)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.1.43)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.10/dist-packages (from wandb) (4.3.6)
# Requirement already satisfied: pydantic<3,>=2.6 in /usr/local/lib/python3.10/dist-packages (from wandb) (2.10.3)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (2.19.2)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.10/dist-packages (from wandb) (1.3.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb) (75.1.0)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.17.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning==1.9.0) (3.11.10)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=2.6->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=2.6->wandb) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.30.2) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.30.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.30.2) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.30.2) (2024.12.14)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->diffusers==0.18.2) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.5.1+cu121) (3.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==1.9.0) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==1.9.0) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==1.9.0) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==1.9.0) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==1.9.0) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==1.9.0) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==1.9.0) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==1.9.0) (1.18.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.1)
# Downloading accelerate-0.19.0-py3-none-any.whl (219 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.1/219.1 kB 12.1 MB/s eta 0:00:00
# Downloading transformers-4.30.2-py3-none-any.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 59.9 MB/s eta 0:00:00
# Downloading diffusers-0.18.2-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 51.6 MB/s eta 0:00:00
# Downloading bitsandbytes-0.40.0.post4-py3-none-any.whl (101.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.8/101.8 MB 7.2 MB/s eta 0:00:00
# Downloading jax-0.4.23-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 26.3 MB/s eta 0:00:00
# Downloading jaxlib-0.4.23-cp310-cp310-manylinux2014_x86_64.whl (77.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.2/77.2 MB 7.8 MB/s eta 0:00:00
# Downloading pytorch_lightning-1.9.0-py3-none-any.whl (825 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 825.8/825.8 kB 37.7 MB/s eta 0:00:00
# Downloading voluptuous-0.13.1-py3-none-any.whl (29 kB)
# Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 4.4 MB/s eta 0:00:00
# Downloading einops-0.6.0-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 kB 3.6 MB/s eta 0:00:00
# Downloading huggingface_hub-0.22.0-py3-none-any.whl (388 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.5/388.5 kB 21.0 MB/s eta 0:00:00
# Downloading invisible_watermark-0.2.0-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 53.8 MB/s eta 0:00:00
# Downloading open_clip_torch-2.20.0-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 57.7 MB/s eta 0:00:00
# Downloading prodigyopt-1.0-py3-none-any.whl (5.5 kB)
# Downloading lion_pytorch-0.1.2-py3-none-any.whl (4.4 kB)
# Downloading lightning_utilities-0.11.9-py3-none-any.whl (28 kB)
# Downloading protobuf-3.20.3-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 58.2 MB/s eta 0:00:00
# Downloading pywavelets-1.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 75.1 MB/s eta 0:00:00
# Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 50.6 MB/s eta 0:00:00
# Downloading torchmetrics-1.6.1-py3-none-any.whl (927 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 927.3/927.3 kB 34.4 MB/s eta 0:00:00
# Building wheels for collected packages: dadaptation
#   Building wheel for dadaptation (pyproject.toml) ... done
#   Created wheel for dadaptation: filename=dadaptation-3.1-py3-none-any.whl size=22789 sha256=8d871431c8f2d114d2f2bcb1fee145ddba2e88745b8ae31b2ae90f4b73b149df
#   Stored in directory: /root/.cache/pip/wheels/34/25/92/b7708738900a69a166f41de56c776039b5a05599b36075c34f
# Successfully built dadaptation
# Installing collected packages: voluptuous, tokenizers, bitsandbytes, PyWavelets, protobuf, prodigyopt, lightning-utilities, ftfy, einops, dadaptation, jaxlib, jax, huggingface-hub, transformers, torchmetrics, lion-pytorch, invisible-watermark, diffusers, accelerate, pytorch-lightning, open-clip-torch
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.21.0
#     Uninstalling tokenizers-0.21.0:
#       Successfully uninstalled tokenizers-0.21.0
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.5
#     Uninstalling protobuf-4.25.5:
#       Successfully uninstalled protobuf-4.25.5
#   Attempting uninstall: einops
#     Found existing installation: einops 0.8.0
#     Uninstalling einops-0.8.0:
#       Successfully uninstalled einops-0.8.0
#   Attempting uninstall: jaxlib
#     Found existing installation: jaxlib 0.4.33
#     Uninstalling jaxlib-0.4.33:
#       Successfully uninstalled jaxlib-0.4.33
#   Attempting uninstall: jax
#     Found existing installation: jax 0.4.33
#     Uninstalling jax-0.4.33:
#       Successfully uninstalled jax-0.4.33
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.27.0
#     Uninstalling huggingface-hub-0.27.0:
#       Successfully uninstalled huggingface-hub-0.27.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.47.1
#     Uninstalling transformers-4.47.1:
#       Successfully uninstalled transformers-4.47.1
#   Attempting uninstall: diffusers
#     Found existing installation: diffusers 0.31.0
#     Uninstalling diffusers-0.31.0:
#       Successfully uninstalled diffusers-0.31.0
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 1.2.1
#     Uninstalling accelerate-1.2.1:
#       Successfully uninstalled accelerate-1.2.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# chex 0.1.88 requires jax>=0.4.27, but you have jax 0.4.23 which is incompatible.
# chex 0.1.88 requires jaxlib>=0.4.27, but you have jaxlib 0.4.23 which is incompatible.
# flax 0.8.5 requires jax>=0.4.27, but you have jax 0.4.23 which is incompatible.
# grpcio-status 1.62.3 requires protobuf>=4.21.6, but you have protobuf 3.20.3 which is incompatible.
# optax 0.2.4 requires jax>=0.4.27, but you have jax 0.4.23 which is incompatible.
# optax 0.2.4 requires jaxlib>=0.4.27, but you have jaxlib 0.4.23 which is incompatible.
# orbax-checkpoint 0.6.4 requires jax>=0.4.26, but you have jax 0.4.23 which is incompatible.
# peft 0.14.0 requires accelerate>=0.21.0, but you have accelerate 0.19.0 which is incompatible.
# peft 0.14.0 requires huggingface-hub>=0.25.0, but you have huggingface-hub 0.22.0 which is incompatible.
# sentence-transformers 3.3.1 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.30.2 which is incompatible.
# Successfully installed PyWavelets-1.8.0 accelerate-0.19.0 bitsandbytes-0.40.0.post4 dadaptation-3.1 diffusers-0.18.2 einops-0.6.0 ftfy-6.1.1 huggingface-hub-0.22.0 invisible-watermark-0.2.0 jax-0.4.23 jaxlib-0.4.23 lightning-utilities-0.11.9 lion-pytorch-0.1.2 open-clip-torch-2.20.0 prodigyopt-1.0 protobuf-3.20.3 pytorch-lightning-1.9.0 tokenizers-0.13.3 torchmetrics-1.6.1 transformers-4.30.2 voluptuous-0.13.1
# Obtaining file:///content/kohya-trainer
#   Preparing metadata (setup.py) ... done
# Installing collected packages: library
#   Running setup.py develop for library
# Successfully installed library-0.0.0
#
# ✅ Installation finished in 88 seconds.
#
# 🔄 Getting model...
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# 🍃 Diffusers model identified.
#
#
# 📄 Config saved to /content/drive/MyDrive/Loras/Realystic_Model/training_config.toml
# 📄 Dataset config saved to /content/drive/MyDrive/Loras/Realystic_Model/dataset_config.toml
#
# ⭐ Starting trainer...
#
# Loading settings from /content/drive/MyDrive/Loras/Realystic_Model/training_config.toml...
# /content/drive/MyDrive/Loras/Realystic_Model/training_config
# prepare tokenizers
# vocab.json: 100% 961k/961k [00:00<00:00, 14.0MB/s]
# merges.txt: 100% 525k/525k [00:00<00:00, 8.29MB/s]
# special_tokens_map.json: 100% 389/389 [00:00<00:00, 2.18MB/s]
# tokenizer_config.json: 100% 905/905 [00:00<00:00, 5.02MB/s]
# vocab.json: 100% 862k/862k [00:00<00:00, 12.5MB/s]
# merges.txt: 100% 525k/525k [00:00<00:00, 4.12MB/s]
# special_tokens_map.json: 100% 389/389 [00:00<00:00, 1.90MB/s]
# tokenizer_config.json: 100% 904/904 [00:00<00:00, 3.99MB/s]
# update token length: 225
# Loading dataset config from /content/drive/MyDrive/Loras/Realystic_Model/dataset_config.toml
# prepare images.
# found directory /content/drive/MyDrive/Loras/Realystic_Model/dataset contains 298 image files
# 89400 train images with repeating.
# 0 reg images.
# no regularization images / 正則化画像が見つかりませんでした
# [Dataset 0]
#   batch_size: 4
#   resolution: (1024, 1024)
#   enable_bucket: True
#   min_bucket_reso: 256
#   max_bucket_reso: 4096
#   bucket_reso_steps: 64
#   bucket_no_upscale: False
#
#   [Subset 0 of Dataset 0]
#     image_dir: "/content/drive/MyDrive/Loras/Realystic_Model/dataset"
#     image_count: 298
#     num_repeats: 300
#     shuffle_caption: True
#     keep_tokens: 1
#     caption_dropout_rate: 0.0
#     caption_dropout_every_n_epoches: 0
#     caption_tag_dropout_rate: 0.0
#     color_aug: False
#     flip_aug: False
#     face_crop_aug_range: None
#     random_crop: False
#     token_warmup_min: 1,
#     token_warmup_step: 0,
#     is_reg: False
#     class_tokens: None
#     caption_extension: .txt
#
#
# [Dataset 0]
# loading image sizes.
# 100% 298/298 [00:01<00:00, 233.25it/s]
# make buckets
# number of images (including repeats) / 各bucketの画像枚数（繰り返し回数を含む）
# bucket 0: resolution (832, 1216), count: 73800
# bucket 1: resolution (1216, 832), count: 15600
# mean ar error (without repeats): 0.006125156588621447
# Warning: SDXL has been trained with noise_offset=0.0357, but noise_offset is disabled due to multires_noise_iterations / SDXLはnoise_offset=0.0357で学習されていますが、multires_noise_iterationsが有効になっているためnoise_offsetは無効になります
# preparing accelerator
# /usr/local/lib/python3.10/dist-packages/accelerate/accelerator.py:432: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(**kwargs)
# loading model for process 0/1
# load Diffusers pretrained models: hollowstrawberry/67AB2F, variant=fp16
# model_index.json: 100% 577/577 [00:00<00:00, 2.86MB/s]
# /usr/local/lib/python3.10/dist-packages/diffusers/pipelines/pipeline_utils.py:1223: FutureWarning: You are trying to load the model files of the `variant=fp16`, but no such modeling files are available.The default model files: {'text_encoder_2/model.safetensors', 'unet/diffusion_pytorch_model.safetensors', 'text_encoder/model.safetensors', 'vae/diffusion_pytorch_model.safetensors'} will be loaded instead. Make sure to not load from `variant=fp16`if such variant modeling files are not available. Doing so will lead to an error in v0.22.0 as defaulting to non-variantmodeling files is deprecated.
#   deprecate("no variant default", "0.22.0", deprecation_message, standard_warn=False)
# Fetching 14 files:   0% 0/14 [00:00<?, ?it/s]
# text_encoder/model.safetensors:   0% 0.00/246M [00:00<?, ?B/s]
#
# scheduler/scheduler_config.json: 100% 474/474 [00:00<00:00, 2.41MB/s]
# Fetching 14 files:  14% 2/14 [00:00<00:01,  9.51it/s]
#
# text_encoder_2/model.safetensors:   0% 0.00/1.39G [00:00<?, ?B/s]
#
#
# text_encoder/config.json: 100% 585/585 [00:00<00:00, 2.55MB/s]
#
#
#
# text_encoder_2/config.json: 100% 595/595 [00:00<00:00, 1.27MB/s]
#
#
#
# tokenizer_2/special_tokens_map.json: 100% 460/460 [00:00<00:00, 3.19MB/s]
#
#
#
# tokenizer_2/merges.txt:   0% 0.00/525k [00:00<?, ?B/s]
#
#
#
# tokenizer_2/tokenizer_config.json: 100% 725/725 [00:00<00:00, 2.06MB/s]
#
#
#
#
# unet/diffusion_pytorch_model.safetensors:   0% 0.00/5.14G [00:00<?, ?B/s]
#
#
#
#
# vae/diffusion_pytorch_model.safetensors:   0% 0.00/167M [00:00<?, ?B/s]
#
#
#
#
#
# tokenizer_2/vocab.json:   0% 0.00/1.06M [00:00<?, ?B/s]
#
#
#
#
#
#
# vae/config.json: 100% 577/577 [00:00<00:00, 3.02MB/s]
#
#
#
#
#
#
#
# unet/config.json: 100% 1.68k/1.68k [00:00<00:00, 7.30MB/s]
#
#
#
# tokenizer_2/merges.txt: 100% 525k/525k [00:00<00:00, 2.39MB/s]
#
# text_encoder/model.safetensors:   4% 10.5M/246M [00:00<00:05, 39.5MB/s]
#
# text_encoder_2/model.safetensors:   1% 10.5M/1.39G [00:00<00:37, 36.8MB/s]
#
#
#
#
# vae/diffusion_pytorch_model.safetensors:   6% 10.5M/167M [00:00<00:03, 39.9MB/s]
#
#
#
#
#
# tokenizer_2/vocab.json: 100% 1.06M/1.06M [00:00<00:00, 4.32MB/s]
#
#
#
#
# unet/diffusion_pytorch_model.safetensors:   0% 10.5M/5.14G [00:00<02:44, 31.2MB/s]
# text_encoder/model.safetensors:   9% 21.0M/246M [00:00<00:05, 40.1MB/s]
#
# text_encoder_2/model.safetensors:   2% 21.0M/1.39G [00:00<00:33, 40.6MB/s]
#
#
#
#
# vae/diffusion_pytorch_model.safetensors:  13% 21.0M/167M [00:00<00:03, 41.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:   0% 21.0M/5.14G [00:00<02:11, 38.8MB/s]
# text_encoder/model.safetensors:  13% 31.5M/246M [00:00<00:05, 42.6MB/s]
#
# text_encoder_2/model.safetensors:   2% 31.5M/1.39G [00:00<00:32, 41.9MB/s]
#
#
#
#
# vae/diffusion_pytorch_model.safetensors:  19% 31.5M/167M [00:00<00:03, 42.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:   1% 31.5M/5.14G [00:00<02:05, 40.8MB/s]
# text_encoder/model.safetensors:  17% 41.9M/246M [00:00<00:04, 43.5MB/s]
#
# text_encoder_2/model.safetensors:   3% 41.9M/1.39G [00:01<00:31, 42.3MB/s]
#
#
#
#
# vae/diffusion_pytorch_model.safetensors:  25% 41.9M/167M [00:00<00:02, 42.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:   1% 41.9M/5.14G [00:01<02:02, 41.4MB/s]
# text_encoder/model.safetensors:  21% 52.4M/246M [00:01<00:04, 42.6MB/s]
#
# text_encoder_2/model.safetensors:   4% 52.4M/1.39G [00:01<00:31, 42.6MB/s]
#
#
#
#
# vae/diffusion_pytorch_model.safetensors:  31% 52.4M/167M [00:01<00:02, 42.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:   1% 52.4M/5.14G [00:01<02:01, 41.9MB/s]
# text_encoder/model.safetensors:  26% 62.9M/246M [00:01<00:04, 43.2MB/s]
#
# text_encoder_2/model.safetensors:   5% 62.9M/1.39G [00:01<00:31, 42.5MB/s]
#
#
#
#
# vae/diffusion_pytorch_model.safetensors:  38% 62.9M/167M [00:01<00:02, 42.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:   1% 62.9M/5.14G [00:01<02:00, 42.2MB/s]
# text_encoder/model.safetensors:  30% 73.4M/246M [00:01<00:04, 43.1MB/s]
#
# text_encoder_2/model.safetensors:   5% 73.4M/1.39G [00:01<00:31, 42.4MB/s]
#
#
#
#
# vae/diffusion_pytorch_model.safetensors:  44% 73.4M/167M [00:01<00:02, 42.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:   1% 73.4M/5.14G [00:01<01:59, 42.5MB/s]
# text_encoder/model.safetensors:  34% 83.9M/246M [00:01<00:03, 42.8MB/s]
#
# text_encoder_2/model.safetensors:   6% 83.9M/1.39G [00:01<00:30, 42.5MB/s]
#
#
#
#
# vae/diffusion_pytorch_model.safetensors:  50% 83.9M/167M [00:01<00:01, 42.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:   2% 83.9M/5.14G [00:02<01:58, 42.6MB/s]
# text_encoder/model.safetensors:  38% 94.4M/246M [00:02<00:03, 42.7MB/s]
#
# text_encoder_2/model.safetensors:   7% 94.4M/1.39G [00:02<00:30, 42.7MB/s]
#
#
#
#
# vae/diffusion_pytorch_model.safetensors:  56% 94.4M/167M [00:02<00:01, 42.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:   2% 94.4M/5.14G [00:02<01:58, 42.6MB/s]
# text_encoder/model.safetensors:  43% 105M/246M [00:02<00:03, 42.5MB/s]
#
# text_encoder_2/model.safetensors:   8% 105M/1.39G [00:02<00:30, 42.5MB/s]
#
#
#
#
# vae/diffusion_pytorch_model.safetensors:  63% 105M/167M [00:02<00:01, 42.7MB/s]
# text_encoder/model.safetensors:  47% 115M/246M [00:03<00:05, 25.0MB/s]
#
# text_encoder_2/model.safetensors:   8% 115M/1.39G [00:03<00:50, 25.1MB/s]
#
#
#
#
# vae/diffusion_pytorch_model.safetensors:  69% 115M/167M [00:03<00:01, 27.6MB/s]
# text_encoder/model.safetensors:  51% 126M/246M [00:03<00:03, 32.2MB/s]
#
# text_encoder_2/model.safetensors:   9% 126M/1.39G [00:03<00:39, 32.0MB/s]
#
#
#
#
# vae/diffusion_pytorch_model.safetensors:  75% 126M/167M [00:03<00:01, 35.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:   2% 105M/5.14G [00:03<03:58, 21.1MB/s]
# text_encoder/model.safetensors:  55% 136M/246M [00:04<00:07, 15.3MB/s]
#
# text_encoder_2/model.safetensors:  10% 136M/1.39G [00:05<01:44, 12.0MB/s]
#
#
#
#
# vae/diffusion_pytorch_model.safetensors:  81% 136M/167M [00:05<00:02, 12.4MB/s]
# text_encoder/model.safetensors:  60% 147M/246M [00:05<00:06, 15.3MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:   2% 115M/5.14G [00:05<07:52, 10.6MB/s]
#
# text_encoder_2/model.safetensors:  11% 147M/1.39G [00:05<01:18, 15.8MB/s]
#
#
#
#
# vae/diffusion_pytorch_model.safetensors:  88% 147M/167M [00:05<00:01, 16.1MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:   2% 126M/5.14G [00:05<05:50, 14.3MB/s]
# text_encoder/model.safetensors:  64% 157M/246M [00:05<00:04, 19.7MB/s]
#
# text_encoder_2/model.safetensors:  11% 157M/1.39G [00:05<01:01, 20.2MB/s]
#
#
#
#
# vae/diffusion_pytorch_model.safetensors:  94% 157M/167M [00:05<00:00, 20.4MB/s]
# text_encoder/model.safetensors:  68% 168M/246M [00:05<00:03, 24.2MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:   3% 136M/5.14G [00:05<04:36, 18.1MB/s]
#
# text_encoder_2/model.safetensors:  12% 168M/1.39G [00:06<00:48, 25.3MB/s]
#
#
#
#
# vae/diffusion_pytorch_model.safetensors: 100% 167M/167M [00:05<00:00, 25.0MB/s]
# text_encoder/model.safetensors:  72% 178M/246M [00:06<00:02, 28.1MB/s]
#
#
#
# vae/diffusion_pytorch_model.safetensors: 100% 167M/167M [00:06<00:00, 27.6MB/s]
#
#
# text_encoder_2/model.safetensors:  13% 178M/1.39G [00:06<00:39, 30.5MB/s]
# text_encoder/model.safetensors:  77% 189M/246M [00:06<00:01, 35.4MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:   3% 157M/5.14G [00:06<03:10, 26.1MB/s]
# text_encoder/model.safetensors:  81% 199M/246M [00:06<00:01, 38.8MB/s]
#
# text_encoder_2/model.safetensors:  14% 189M/1.39G [00:06<00:36, 32.8MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:   3% 168M/5.14G [00:06<02:47, 29.6MB/s]
#
# text_encoder_2/model.safetensors:  14% 199M/1.39G [00:06<00:33, 35.7MB/s]
# text_encoder/model.safetensors:  85% 210M/246M [00:06<00:00, 40.0MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:   3% 178M/5.14G [00:06<02:31, 32.7MB/s]
#
# text_encoder_2/model.safetensors:  15% 210M/1.39G [00:06<00:31, 37.6MB/s]
# text_encoder/model.safetensors:  89% 220M/246M [00:07<00:00, 40.9MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:   4% 189M/5.14G [00:06<02:20, 35.2MB/s]
#
# text_encoder_2/model.safetensors:  16% 220M/1.39G [00:07<00:30, 38.9MB/s]
# text_encoder/model.safetensors:  94% 231M/246M [00:07<00:00, 41.3MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:   4% 199M/5.14G [00:07<02:12, 37.3MB/s]
#
# text_encoder_2/model.safetensors:  17% 231M/1.39G [00:07<00:28, 40.1MB/s]
# text_encoder/model.safetensors:  98% 241M/246M [00:07<00:00, 41.7MB/s]
# text_encoder/model.safetensors: 100% 246M/246M [00:07<00:00, 32.2MB/s]
# Fetching 14 files:  29% 4/14 [00:07<00:22,  2.29s/it]
#
#
#
# unet/diffusion_pytorch_model.safetensors:   4% 210M/5.14G [00:07<02:07, 38.8MB/s]
#
# text_encoder_2/model.safetensors:  17% 241M/1.39G [00:07<00:28, 40.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:   4% 220M/5.14G [00:07<02:03, 39.8MB/s]
#
# text_encoder_2/model.safetensors:  18% 252M/1.39G [00:07<00:27, 41.3MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:   4% 231M/5.14G [00:07<02:00, 40.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:   5% 241M/5.14G [00:08<01:58, 41.4MB/s]
#
# text_encoder_2/model.safetensors:  19% 262M/1.39G [00:08<00:35, 32.0MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:   5% 252M/5.14G [00:08<01:56, 41.8MB/s]
#
# text_encoder_2/model.safetensors:  20% 273M/1.39G [00:08<00:31, 35.4MB/s]
#
# text_encoder_2/model.safetensors:  20% 283M/1.39G [00:08<00:25, 42.9MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:   5% 262M/5.14G [00:08<01:56, 41.9MB/s]
#
# text_encoder_2/model.safetensors:  21% 294M/1.39G [00:08<00:22, 48.9MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:   5% 273M/5.14G [00:08<01:54, 42.3MB/s]
#
# text_encoder_2/model.safetensors:  22% 304M/1.39G [00:09<00:22, 47.3MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:   6% 283M/5.14G [00:09<01:54, 42.5MB/s]
#
# text_encoder_2/model.safetensors:  23% 315M/1.39G [00:09<00:23, 46.0MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:   6% 294M/5.14G [00:09<01:53, 42.6MB/s]
#
# text_encoder_2/model.safetensors:  23% 325M/1.39G [00:09<00:23, 45.1MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:   6% 304M/5.14G [00:09<01:53, 42.6MB/s]
#
# text_encoder_2/model.safetensors:  24% 336M/1.39G [00:09<00:24, 43.9MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:   6% 315M/5.14G [00:09<01:52, 42.7MB/s]
#
# text_encoder_2/model.safetensors:  25% 346M/1.39G [00:10<00:24, 43.4MB/s]
#
# text_encoder_2/model.safetensors:  26% 357M/1.39G [00:10<00:23, 43.1MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:   6% 325M/5.14G [00:10<02:11, 36.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:   7% 336M/5.14G [00:10<01:46, 44.9MB/s]
#
# text_encoder_2/model.safetensors:  26% 367M/1.39G [00:10<00:23, 43.1MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:   7% 346M/5.14G [00:10<01:48, 44.3MB/s]
#
# text_encoder_2/model.safetensors:  27% 377M/1.39G [00:10<00:23, 43.1MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:   7% 357M/5.14G [00:10<01:49, 43.6MB/s]
#
# text_encoder_2/model.safetensors:  28% 388M/1.39G [00:11<00:23, 43.1MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:   7% 367M/5.14G [00:11<01:50, 43.2MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:   7% 377M/5.14G [00:11<01:49, 43.3MB/s]
#
# text_encoder_2/model.safetensors:  29% 398M/1.39G [00:11<00:29, 34.0MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:   8% 388M/5.14G [00:11<01:50, 43.1MB/s]
#
# text_encoder_2/model.safetensors:  30% 419M/1.39G [00:11<00:21, 45.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:   8% 398M/5.14G [00:11<01:50, 43.0MB/s]
#
# text_encoder_2/model.safetensors:  31% 430M/1.39G [00:12<00:21, 44.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:   8% 409M/5.14G [00:12<01:49, 43.2MB/s]
#
# text_encoder_2/model.safetensors:  32% 440M/1.39G [00:12<00:21, 43.9MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:   8% 419M/5.14G [00:12<01:49, 43.1MB/s]
#
# text_encoder_2/model.safetensors:  32% 451M/1.39G [00:12<00:21, 43.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:   8% 430M/5.14G [00:12<01:49, 42.9MB/s]
#
# text_encoder_2/model.safetensors:  33% 461M/1.39G [00:12<00:21, 43.2MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:   9% 440M/5.14G [00:12<01:49, 42.7MB/s]
#
# text_encoder_2/model.safetensors:  34% 472M/1.39G [00:13<00:21, 43.1MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:   9% 451M/5.14G [00:13<01:49, 42.6MB/s]
#
# text_encoder_2/model.safetensors:  35% 482M/1.39G [00:13<00:21, 42.9MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:   9% 461M/5.14G [00:13<01:50, 42.4MB/s]
#
# text_encoder_2/model.safetensors:  35% 493M/1.39G [00:13<00:20, 42.9MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:   9% 472M/5.14G [00:13<01:49, 42.6MB/s]
#
# text_encoder_2/model.safetensors:  36% 503M/1.39G [00:13<00:20, 42.9MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:   9% 482M/5.14G [00:13<01:49, 42.5MB/s]
#
# text_encoder_2/model.safetensors:  37% 514M/1.39G [00:14<00:20, 42.8MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  10% 493M/5.14G [00:14<01:48, 42.7MB/s]
#
# text_encoder_2/model.safetensors:  38% 524M/1.39G [00:14<00:20, 42.9MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  10% 503M/5.14G [00:14<01:48, 42.6MB/s]
#
# text_encoder_2/model.safetensors:  38% 535M/1.39G [00:14<00:19, 42.9MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  10% 514M/5.14G [00:14<01:48, 42.7MB/s]
#
# text_encoder_2/model.safetensors:  39% 545M/1.39G [00:14<00:19, 42.8MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  10% 524M/5.14G [00:14<01:47, 42.8MB/s]
#
# text_encoder_2/model.safetensors:  40% 556M/1.39G [00:15<00:19, 42.8MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  10% 535M/5.14G [00:15<01:47, 42.6MB/s]
#
# text_encoder_2/model.safetensors:  41% 566M/1.39G [00:15<00:19, 42.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  11% 545M/5.14G [00:15<01:47, 42.8MB/s]
#
# text_encoder_2/model.safetensors:  42% 577M/1.39G [00:15<00:19, 42.4MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  11% 556M/5.14G [00:15<01:47, 42.6MB/s]
#
# text_encoder_2/model.safetensors:  42% 587M/1.39G [00:15<00:18, 42.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  11% 566M/5.14G [00:15<01:47, 42.6MB/s]
#
# text_encoder_2/model.safetensors:  43% 598M/1.39G [00:16<00:18, 42.3MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  11% 577M/5.14G [00:16<01:47, 42.5MB/s]
#
# text_encoder_2/model.safetensors:  44% 608M/1.39G [00:16<00:18, 42.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  11% 587M/5.14G [00:16<01:46, 42.7MB/s]
#
# text_encoder_2/model.safetensors:  45% 619M/1.39G [00:16<00:18, 42.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  12% 598M/5.14G [00:16<01:46, 42.6MB/s]
#
# text_encoder_2/model.safetensors:  45% 629M/1.39G [00:16<00:17, 42.4MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  12% 608M/5.14G [00:16<01:46, 42.7MB/s]
#
# text_encoder_2/model.safetensors:  46% 640M/1.39G [00:17<00:17, 42.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  12% 619M/5.14G [00:17<01:45, 42.9MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  12% 629M/5.14G [00:19<07:07, 10.5MB/s]
#
# text_encoder_2/model.safetensors:  47% 650M/1.39G [00:20<01:14, 9.87MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  12% 640M/5.14G [00:19<05:14, 14.3MB/s]
#
# text_encoder_2/model.safetensors:  48% 661M/1.39G [00:20<00:54, 13.3MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  13% 650M/5.14G [00:20<04:07, 18.2MB/s]
#
# text_encoder_2/model.safetensors:  48% 671M/1.39G [00:20<00:40, 17.9MB/s]
#
# text_encoder_2/model.safetensors:  49% 682M/1.39G [00:20<00:32, 21.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  13% 661M/5.14G [00:20<03:41, 20.2MB/s]
#
# text_encoder_2/model.safetensors:  50% 692M/1.39G [00:20<00:27, 25.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  13% 671M/5.14G [00:20<02:50, 26.2MB/s]
#
# text_encoder_2/model.safetensors:  51% 703M/1.39G [00:21<00:23, 29.0MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  13% 682M/5.14G [00:20<02:28, 29.9MB/s]
#
# text_encoder_2/model.safetensors:  51% 713M/1.39G [00:21<00:20, 32.2MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  13% 692M/5.14G [00:21<02:15, 32.9MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  14% 703M/5.14G [00:21<02:04, 35.5MB/s]
#
# text_encoder_2/model.safetensors:  52% 724M/1.39G [00:21<00:19, 34.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  14% 713M/5.14G [00:21<01:57, 37.5MB/s]
#
# text_encoder_2/model.safetensors:  53% 734M/1.39G [00:21<00:17, 36.8MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  14% 724M/5.14G [00:21<01:53, 38.9MB/s]
#
# text_encoder_2/model.safetensors:  54% 744M/1.39G [00:22<00:16, 38.3MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  14% 734M/5.14G [00:22<01:50, 39.9MB/s]
#
# text_encoder_2/model.safetensors:  54% 755M/1.39G [00:22<00:16, 39.3MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  14% 744M/5.14G [00:22<01:47, 40.7MB/s]
#
# text_encoder_2/model.safetensors:  55% 765M/1.39G [00:22<00:15, 40.1MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  15% 755M/5.14G [00:22<01:45, 41.4MB/s]
#
# text_encoder_2/model.safetensors:  56% 776M/1.39G [00:22<00:15, 39.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  15% 765M/5.14G [00:22<01:44, 41.9MB/s]
#
# text_encoder_2/model.safetensors:  57% 786M/1.39G [00:23<00:14, 41.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  15% 776M/5.14G [00:23<01:44, 41.9MB/s]
#
# text_encoder_2/model.safetensors:  57% 797M/1.39G [00:23<00:14, 41.9MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  15% 786M/5.14G [00:23<01:43, 42.2MB/s]
#
# text_encoder_2/model.safetensors:  58% 807M/1.39G [00:23<00:13, 42.1MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  16% 797M/5.14G [00:23<01:42, 42.2MB/s]
#
# text_encoder_2/model.safetensors:  59% 818M/1.39G [00:23<00:13, 42.0MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  16% 807M/5.14G [00:23<01:42, 42.2MB/s]
#
# text_encoder_2/model.safetensors:  60% 828M/1.39G [00:24<00:13, 42.3MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  16% 818M/5.14G [00:24<01:42, 42.3MB/s]
#
# text_encoder_2/model.safetensors:  60% 839M/1.39G [00:24<00:12, 42.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  16% 828M/5.14G [00:24<01:41, 42.4MB/s]
#
# text_encoder_2/model.safetensors:  61% 849M/1.39G [00:24<00:12, 42.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  16% 839M/5.14G [00:24<01:40, 42.5MB/s]
#
# text_encoder_2/model.safetensors:  62% 860M/1.39G [00:24<00:12, 42.4MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  17% 849M/5.14G [00:24<01:40, 42.7MB/s]
#
# text_encoder_2/model.safetensors:  63% 870M/1.39G [00:25<00:12, 42.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  17% 860M/5.14G [00:25<01:39, 42.9MB/s]
#
# text_encoder_2/model.safetensors:  63% 881M/1.39G [00:25<00:11, 42.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  17% 870M/5.14G [00:25<01:39, 42.8MB/s]
#
# text_encoder_2/model.safetensors:  64% 891M/1.39G [00:25<00:11, 42.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  17% 881M/5.14G [00:25<01:39, 42.9MB/s]
#
# text_encoder_2/model.safetensors:  65% 902M/1.39G [00:25<00:11, 42.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  17% 891M/5.14G [00:25<01:39, 42.7MB/s]
#
# text_encoder_2/model.safetensors:  66% 912M/1.39G [00:25<00:11, 42.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  18% 902M/5.14G [00:26<01:39, 42.5MB/s]
#
# text_encoder_2/model.safetensors:  66% 923M/1.39G [00:26<00:10, 42.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  18% 912M/5.14G [00:26<01:38, 42.7MB/s]
#
# text_encoder_2/model.safetensors:  67% 933M/1.39G [00:26<00:10, 42.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  18% 923M/5.14G [00:26<01:39, 42.5MB/s]
#
# text_encoder_2/model.safetensors:  68% 944M/1.39G [00:26<00:10, 42.8MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  18% 933M/5.14G [00:26<01:38, 42.5MB/s]
#
# text_encoder_2/model.safetensors:  69% 954M/1.39G [00:26<00:10, 42.4MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  18% 944M/5.14G [00:27<01:38, 42.7MB/s]
#
# text_encoder_2/model.safetensors:  69% 965M/1.39G [00:27<00:09, 42.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  19% 954M/5.14G [00:27<01:38, 42.5MB/s]
#
# text_encoder_2/model.safetensors:  70% 975M/1.39G [00:27<00:09, 42.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  19% 965M/5.14G [00:27<01:37, 42.7MB/s]
#
# text_encoder_2/model.safetensors:  71% 986M/1.39G [00:27<00:09, 42.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  19% 975M/5.14G [00:27<01:37, 42.8MB/s]
#
# text_encoder_2/model.safetensors:  72% 996M/1.39G [00:27<00:09, 42.3MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  19% 986M/5.14G [00:28<01:37, 42.7MB/s]
#
# text_encoder_2/model.safetensors:  72% 1.01G/1.39G [00:28<00:08, 42.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  19% 996M/5.14G [00:28<01:37, 42.6MB/s]
#
# text_encoder_2/model.safetensors:  73% 1.02G/1.39G [00:28<00:08, 42.4MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  20% 1.01G/5.14G [00:28<01:36, 42.6MB/s]
#
# text_encoder_2/model.safetensors:  74% 1.03G/1.39G [00:28<00:08, 41.4MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  20% 1.02G/5.14G [00:28<01:36, 42.5MB/s]
#
# text_encoder_2/model.safetensors:  75% 1.04G/1.39G [00:28<00:08, 43.3MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  20% 1.03G/5.14G [00:28<01:36, 42.6MB/s]
#
# text_encoder_2/model.safetensors:  75% 1.05G/1.39G [00:29<00:08, 42.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  20% 1.04G/5.14G [00:29<01:36, 42.3MB/s]
#
# text_encoder_2/model.safetensors:  76% 1.06G/1.39G [00:29<00:07, 42.4MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  20% 1.05G/5.14G [00:29<01:36, 42.2MB/s]
#
# text_encoder_2/model.safetensors:  77% 1.07G/1.39G [00:29<00:07, 42.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  21% 1.06G/5.14G [00:29<01:36, 42.2MB/s]
#
# text_encoder_2/model.safetensors:  78% 1.08G/1.39G [00:29<00:07, 42.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  21% 1.07G/5.14G [00:29<01:35, 42.4MB/s]
#
# text_encoder_2/model.safetensors:  78% 1.09G/1.39G [00:30<00:06, 42.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  21% 1.08G/5.14G [00:30<01:35, 42.6MB/s]
#
# text_encoder_2/model.safetensors:  79% 1.10G/1.39G [00:30<00:06, 42.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  21% 1.09G/5.14G [00:30<01:34, 42.8MB/s]
#
# text_encoder_2/model.safetensors:  80% 1.11G/1.39G [00:30<00:06, 42.8MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  21% 1.10G/5.14G [00:30<01:34, 42.8MB/s]
#
# text_encoder_2/model.safetensors:  81% 1.12G/1.39G [00:30<00:06, 42.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  22% 1.11G/5.14G [00:30<01:34, 42.7MB/s]
#
# text_encoder_2/model.safetensors:  82% 1.13G/1.39G [00:31<00:06, 42.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  22% 1.12G/5.14G [00:31<01:34, 42.5MB/s]
#
# text_encoder_2/model.safetensors:  82% 1.14G/1.39G [00:31<00:05, 42.4MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  22% 1.13G/5.14G [00:31<01:33, 42.7MB/s]
#
# text_encoder_2/model.safetensors:  83% 1.15G/1.39G [00:31<00:06, 35.7MB/s]
#
# text_encoder_2/model.safetensors:  84% 1.16G/1.39G [00:31<00:05, 43.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  22% 1.14G/5.14G [00:31<01:52, 35.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  22% 1.15G/5.14G [00:31<01:31, 43.6MB/s]
#
# text_encoder_2/model.safetensors:  85% 1.17G/1.39G [00:32<00:04, 44.4MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  23% 1.16G/5.14G [00:32<01:27, 45.3MB/s]
#
# text_encoder_2/model.safetensors:  85% 1.18G/1.39G [00:32<00:04, 44.2MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  23% 1.17G/5.14G [00:32<01:29, 44.4MB/s]
#
# text_encoder_2/model.safetensors:  86% 1.20G/1.39G [00:32<00:04, 43.8MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  23% 1.18G/5.14G [00:32<01:29, 44.1MB/s]
#
# text_encoder_2/model.safetensors:  87% 1.21G/1.39G [00:32<00:04, 43.4MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  23% 1.20G/5.14G [00:32<01:29, 43.8MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  23% 1.21G/5.14G [00:33<02:09, 30.4MB/s]
#
# text_encoder_2/model.safetensors:  88% 1.22G/1.39G [00:33<00:06, 25.2MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  24% 1.22G/5.14G [00:33<01:41, 38.4MB/s]
#
# text_encoder_2/model.safetensors:  88% 1.23G/1.39G [00:33<00:05, 29.3MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  24% 1.23G/5.14G [00:33<01:37, 40.2MB/s]
#
# text_encoder_2/model.safetensors:  89% 1.24G/1.39G [00:34<00:04, 36.4MB/s]
#
# text_encoder_2/model.safetensors:  90% 1.25G/1.39G [00:34<00:03, 43.2MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  24% 1.24G/5.14G [00:34<01:35, 41.0MB/s]
#
# text_encoder_2/model.safetensors:  91% 1.26G/1.39G [00:34<00:03, 43.1MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  24% 1.25G/5.14G [00:34<01:33, 41.5MB/s]
#
# text_encoder_2/model.safetensors:  91% 1.27G/1.39G [00:34<00:02, 42.8MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  25% 1.26G/5.14G [00:34<01:32, 41.8MB/s]
#
# text_encoder_2/model.safetensors:  92% 1.28G/1.39G [00:34<00:02, 42.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  25% 1.27G/5.14G [00:34<01:31, 42.0MB/s]
#
# text_encoder_2/model.safetensors:  93% 1.29G/1.39G [00:35<00:02, 42.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  25% 1.28G/5.14G [00:35<01:32, 41.7MB/s]
#
# text_encoder_2/model.safetensors:  94% 1.30G/1.39G [00:35<00:02, 42.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  25% 1.29G/5.14G [00:35<01:30, 42.6MB/s]
#
# text_encoder_2/model.safetensors:  94% 1.31G/1.39G [00:35<00:01, 42.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  25% 1.30G/5.14G [00:35<01:30, 42.6MB/s]
#
# text_encoder_2/model.safetensors:  95% 1.32G/1.39G [00:35<00:01, 42.9MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  26% 1.31G/5.14G [00:35<01:30, 42.4MB/s]
#
# ...
#
#
#
# unet/diffusion_pytorch_model.safetensors:  68% 3.51G/5.14G [01:27<00:38, 42.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  69% 3.52G/5.14G [01:27<00:38, 42.3MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  69% 3.53G/5.14G [01:27<00:37, 42.2MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  69% 3.54G/5.14G [01:28<00:37, 42.3MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  69% 3.55G/5.14G [01:28<00:37, 42.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  69% 3.57G/5.14G [01:28<00:36, 42.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  70% 3.58G/5.14G [01:28<00:36, 42.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  70% 3.59G/5.14G [01:29<00:36, 42.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  70% 3.60G/5.14G [01:29<00:36, 42.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  70% 3.61G/5.14G [01:29<00:37, 41.1MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  70% 3.62G/5.14G [01:29<00:35, 43.0MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  71% 3.63G/5.14G [01:30<00:35, 42.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  71% 3.64G/5.14G [01:30<00:35, 42.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  71% 3.65G/5.14G [01:30<00:34, 42.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  71% 3.66G/5.14G [01:30<00:34, 42.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  71% 3.67G/5.14G [01:31<00:34, 42.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  72% 3.68G/5.14G [01:31<00:34, 42.4MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  72% 3.69G/5.14G [01:31<00:33, 42.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  72% 3.70G/5.14G [01:31<00:33, 42.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  72% 3.71G/5.14G [01:32<00:33, 42.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  72% 3.72G/5.14G [01:32<00:33, 42.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  73% 3.73G/5.14G [01:32<00:33, 42.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  73% 3.74G/5.14G [01:32<00:32, 42.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  73% 3.75G/5.14G [01:33<00:32, 42.8MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  73% 3.76G/5.14G [01:33<00:32, 42.8MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  74% 3.77G/5.14G [01:33<00:31, 42.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  74% 3.79G/5.14G [01:33<00:31, 42.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  74% 3.80G/5.14G [01:34<00:31, 42.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  74% 3.81G/5.14G [01:34<00:31, 42.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  74% 3.82G/5.14G [01:34<00:30, 42.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  75% 3.83G/5.14G [01:34<00:30, 42.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  75% 3.84G/5.14G [01:35<00:30, 42.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  75% 3.85G/5.14G [01:35<00:30, 42.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  75% 3.86G/5.14G [01:35<00:29, 42.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  75% 3.87G/5.14G [01:35<00:29, 42.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  76% 3.88G/5.14G [01:36<00:29, 42.4MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  76% 3.89G/5.14G [01:36<00:29, 42.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  76% 3.90G/5.14G [01:36<00:28, 42.8MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  76% 3.91G/5.14G [01:36<00:28, 42.8MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  76% 3.92G/5.14G [01:37<00:28, 42.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  77% 3.93G/5.14G [01:37<00:28, 42.8MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  77% 3.94G/5.14G [01:37<00:28, 42.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  77% 3.95G/5.14G [01:37<00:27, 42.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  77% 3.96G/5.14G [01:38<00:27, 42.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  77% 3.97G/5.14G [01:38<00:27, 42.3MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  78% 3.98G/5.14G [01:38<00:26, 42.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  78% 4.00G/5.14G [01:38<00:26, 42.4MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  78% 4.01G/5.14G [01:39<00:26, 42.4MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  78% 4.02G/5.14G [01:39<00:26, 42.3MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  78% 4.03G/5.14G [01:39<00:26, 42.4MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  79% 4.04G/5.14G [01:39<00:25, 42.4MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  79% 4.05G/5.14G [01:40<00:25, 42.1MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  79% 4.06G/5.14G [01:40<00:25, 42.0MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  79% 4.07G/5.14G [01:40<00:25, 41.9MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  79% 4.08G/5.14G [01:40<00:25, 42.1MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  80% 4.09G/5.14G [01:41<00:24, 42.4MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  80% 4.10G/5.14G [01:41<00:24, 42.3MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  80% 4.11G/5.14G [01:41<00:24, 42.4MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  80% 4.12G/5.14G [01:41<00:23, 42.4MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  80% 4.13G/5.14G [01:42<00:23, 42.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  81% 4.14G/5.14G [01:42<00:23, 42.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  81% 4.15G/5.14G [01:42<00:23, 42.4MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  81% 4.16G/5.14G [01:42<00:22, 42.4MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  81% 4.17G/5.14G [01:43<00:22, 42.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  81% 4.18G/5.14G [01:43<00:22, 42.4MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  82% 4.19G/5.14G [01:43<00:22, 42.4MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  82% 4.20G/5.14G [01:43<00:21, 42.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  82% 4.22G/5.14G [01:44<00:21, 42.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  82% 4.23G/5.14G [01:44<00:21, 42.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  82% 4.24G/5.14G [01:44<00:21, 42.4MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  83% 4.25G/5.14G [01:44<00:20, 42.4MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  83% 4.26G/5.14G [01:45<00:20, 42.3MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  83% 4.27G/5.14G [01:45<00:20, 42.4MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  83% 4.28G/5.14G [01:45<00:20, 42.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  84% 4.29G/5.14G [01:45<00:19, 42.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  84% 4.30G/5.14G [01:45<00:19, 42.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  84% 4.31G/5.14G [01:46<00:19, 42.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  84% 4.32G/5.14G [01:46<00:19, 42.4MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  84% 4.33G/5.14G [01:46<00:18, 42.4MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  85% 4.34G/5.14G [01:46<00:18, 42.4MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  85% 4.35G/5.14G [01:47<00:18, 42.3MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  85% 4.36G/5.14G [01:47<00:18, 42.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  85% 4.37G/5.14G [01:47<00:17, 42.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  85% 4.38G/5.14G [01:47<00:17, 42.8MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  86% 4.39G/5.14G [01:48<00:17, 42.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  86% 4.40G/5.14G [01:48<00:17, 42.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  86% 4.41G/5.14G [01:48<00:16, 42.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  86% 4.42G/5.14G [01:48<00:16, 42.8MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  86% 4.44G/5.14G [01:49<00:16, 42.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  87% 4.45G/5.14G [01:49<00:16, 42.8MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  87% 4.46G/5.14G [01:49<00:15, 42.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  87% 4.47G/5.14G [01:49<00:15, 42.4MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  87% 4.48G/5.14G [01:50<00:15, 42.4MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  87% 4.49G/5.14G [01:50<00:15, 42.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  88% 4.50G/5.14G [01:50<00:14, 42.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  88% 4.51G/5.14G [01:50<00:14, 42.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  88% 4.52G/5.14G [01:51<00:14, 42.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  88% 4.53G/5.14G [01:51<00:14, 42.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  88% 4.54G/5.14G [01:51<00:13, 42.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  89% 4.55G/5.14G [01:51<00:15, 38.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  89% 4.56G/5.14G [01:52<00:12, 44.2MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  89% 4.57G/5.14G [01:52<00:12, 43.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  89% 4.58G/5.14G [01:52<00:12, 43.3MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  89% 4.59G/5.14G [01:52<00:12, 43.2MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  90% 4.60G/5.14G [01:53<00:12, 43.0MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  90% 4.61G/5.14G [01:53<00:12, 42.8MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  90% 4.62G/5.14G [01:53<00:11, 42.8MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  90% 4.63G/5.14G [01:53<00:11, 42.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  90% 4.65G/5.14G [01:54<00:11, 42.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  91% 4.66G/5.14G [01:54<00:11, 42.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  91% 4.67G/5.14G [01:54<00:10, 42.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  91% 4.68G/5.14G [01:54<00:10, 42.8MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  91% 4.69G/5.14G [01:55<00:10, 42.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  91% 4.70G/5.14G [01:55<00:10, 42.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  92% 4.71G/5.14G [01:55<00:10, 42.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  92% 4.72G/5.14G [01:55<00:09, 42.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  92% 4.73G/5.14G [01:56<00:09, 42.8MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  92% 4.74G/5.14G [01:56<00:09, 42.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  93% 4.75G/5.14G [01:56<00:09, 42.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  93% 4.76G/5.14G [01:56<00:08, 42.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  93% 4.77G/5.14G [01:57<00:08, 42.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  93% 4.78G/5.14G [01:57<00:08, 42.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  93% 4.79G/5.14G [01:57<00:08, 42.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  94% 4.80G/5.14G [01:57<00:07, 42.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  94% 4.81G/5.14G [01:58<00:07, 42.9MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  94% 4.82G/5.14G [01:58<00:07, 42.8MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  94% 4.83G/5.14G [01:58<00:07, 42.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  94% 4.84G/5.14G [01:58<00:06, 42.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  95% 4.85G/5.14G [01:59<00:06, 42.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  95% 4.87G/5.14G [01:59<00:06, 42.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  95% 4.88G/5.14G [01:59<00:06, 42.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  95% 4.89G/5.14G [01:59<00:05, 42.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  95% 4.90G/5.14G [02:00<00:05, 42.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  96% 4.91G/5.14G [02:00<00:05, 42.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  96% 4.92G/5.14G [02:00<00:05, 42.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  96% 4.93G/5.14G [02:00<00:04, 42.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  96% 4.94G/5.14G [02:00<00:04, 42.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  96% 4.95G/5.14G [02:01<00:04, 42.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  97% 4.96G/5.14G [02:01<00:04, 42.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  97% 4.97G/5.14G [02:01<00:03, 42.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  97% 4.98G/5.14G [02:01<00:03, 42.4MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  97% 4.99G/5.14G [02:02<00:03, 42.4MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  97% 5.00G/5.14G [02:02<00:03, 42.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  98% 5.01G/5.14G [02:02<00:02, 42.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  98% 5.02G/5.14G [02:02<00:02, 42.4MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  98% 5.03G/5.14G [02:03<00:02, 42.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  98% 5.04G/5.14G [02:03<00:02, 42.4MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  98% 5.05G/5.14G [02:03<00:01, 42.4MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  99% 5.06G/5.14G [02:03<00:01, 42.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  99% 5.08G/5.14G [02:04<00:01, 42.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  99% 5.09G/5.14G [02:04<00:01, 42.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  99% 5.10G/5.14G [02:04<00:00, 42.5MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors:  99% 5.11G/5.14G [02:04<00:00, 42.6MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors: 100% 5.12G/5.14G [02:05<00:00, 42.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors: 100% 5.13G/5.14G [02:05<00:00, 42.7MB/s]
#
#
#
# unet/diffusion_pytorch_model.safetensors: 100% 5.14G/5.14G [02:05<00:00, 40.9MB/s]
# Fetching 14 files: 100% 14/14 [02:06<00:00,  9.00s/it]
# U-Net converted to original U-Net
# load VAE: stabilityai/sdxl-vae
# config.json: 100% 607/607 [00:00<00:00, 2.66MB/s]
# diffusion_pytorch_model.safetensors: 100% 335M/335M [00:01<00:00, 207MB/s]
# additional VAE loaded
# Enable SDPA for U-Net
# import network module: networks.lora
# [Dataset 0]
# caching latents.
# checking cache validity...
# 100% 298/298 [00:00<00:00, 8110.46it/s]
# caching latents...
# 100% 298/298 [06:17<00:00,  1.27s/it]
# create LoRA network. base dim (rank): 32, alpha: 32
# neuron dropout: p=None, rank dropout: p=None, module dropout: p=None
# create LoRA for Text Encoder 1:
# create LoRA for Text Encoder 2:
# create LoRA for Text Encoder: 264 modules.
# create LoRA for U-Net: 722 modules.
# enable LoRA for text encoder
# enable LoRA for U-Net
# prepare optimizer, data loader etc.
# bin /usr/local/lib/python3.10/dist-packages/bitsandbytes/libbitsandbytes_cuda122.so
# use 8-bit AdamW optimizer | {'weight_decay': 0.1, 'betas': [0.9, 0.99]}
# /usr/local/lib/python3.10/dist-packages/accelerate/accelerator.py:1256: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   model.forward = torch.cuda.amp.autocast(dtype=torch.float16)(model.forward)
# running training / 学習開始
#   num train images * repeats / 学習画像の数×繰り返し回数: 89400
#   num reg images / 正則化画像の数: 0
#   num batches per epoch / 1epochのバッチ数: 22350
#   num epochs / epoch数: 1
#   batch size per device / バッチサイズ: 4
#   gradient accumulation steps / 勾配を合計するステップ数 = 1
#   total optimization steps / 学習ステップ数: 2000
# steps:   0% 0/2000 [00:00<?, ?it/s]
# epoch 1/1
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# steps: 100% 2000/2000 [4:19:02<00:00,  7.77s/it, loss=nan]
# saving checkpoint: /content/drive/MyDrive/Loras/Realystic_Model/output/Realystic_Model-01.safetensors
# model saved.
# steps: 100% 2000/2000 [4:19:05<00:00,  7.77s/it, loss=nan]
# ### ✅ Done! [Go download your Lora from Google Drive](https://drive.google.com/drive/my-drive)
# ### There will be several files, you should try the latest version (the file with the largest number next to it)

# %% [markdown]
# ## *️⃣ Extras
#
# You can run these before starting the training.

# %% [markdown]
# ### 📚 Multiple folders in dataset
# Below is a template allowing you to define multiple folders in your dataset. You must include the location of each folder and you can set different number of repeats for each one. To add more folders simply copy and paste the sections starting with `[[datasets.subsets]]`.
#
# When enabling this, the number of repeats set in the main cell will be ignored, and the main folder set by the project name will also be ignored.
#
# You can make one of them a regularization folder by adding `is_reg = true`
# You can also set different `keep_tokens`, `flip_aug`, etc.

# %%
custom_dataset = """
[[datasets]]

[[datasets.subsets]]
image_dir = "/content/drive/MyDrive/Loras/example/dataset/good_images"
num_repeats = 3

[[datasets.subsets]]
image_dir = "/content/drive/MyDrive/Loras/example/dataset/normal_images"
num_repeats = 1

"""

# %%
custom_dataset = None

# %%
#@markdown ### 📂 Unzip dataset
#@markdown It's much slower to upload individual files to your Drive, so you may want to upload a zip if you have your dataset in your computer.
zip = "/content/drive/MyDrive/my_dataset.zip" #@param {type:"string"}
extract_to = "/content/drive/MyDrive/Loras/example/dataset" #@param {type:"string"}

import os, zipfile

if not os.path.exists('/content/drive'):
  from google.colab import drive
  print("📂 Connecting to Google Drive...")
  drive.mount('/content/drive')

os.makedirs(extract_to, exist_ok=True)

with zipfile.ZipFile(zip, 'r') as f:
  f.extractall(extract_to)

print("✅ Done")

# %%
#@markdown ### 🔢 Count datasets
#@markdown Google Drive makes it impossible to count the files in a folder, so this will show you the file counts in all folders and subfolders.
folder = "/content/drive/MyDrive/Loras" #@param {type:"string"}

import os
from google.colab import drive

if not os.path.exists('/content/drive'):
    print("📂 Connecting to Google Drive...\n")
    drive.mount('/content/drive')

tree = {}
exclude = ("_logs", "/output")
for i, (root, dirs, files) in enumerate(os.walk(folder, topdown=True)):
  dirs[:] = [d for d in dirs if all(ex not in d for ex in exclude)]
  images = len([f for f in files if f.lower().endswith((".png", ".jpg", ".jpeg"))])
  captions = len([f for f in files if f.lower().endswith(".txt")])
  others = len(files) - images - captions
  path = root[folder.rfind("/")+1:]
  tree[path] = None if not images else f"{images:>4} images | {captions:>4} captions |"
  if tree[path] and others:
    tree[path] += f" {others:>4} other files"

pad = max(len(k) for k in tree)
print("\n".join(f"📁{k.ljust(pad)} | {v}" for k, v in tree.items() if v))

# %%
#@markdown ### ↪️ Continue

#@markdown Here you can write a path in your Google Drive to load an existing Lora file to continue training on.<p>
#@markdown **Warning:** It's not the same as one long training session. The epochs start from scratch, and it may have worse results.
continue_from_lora = "" #@param {type:"string"}
if continue_from_lora and not continue_from_lora.startswith("/content/drive/MyDrive"):
  import os
  continue_from_lora = os.path.join("/content/drive/MyDrive", continue_from_lora)

# %% [markdown]
# # 📈 Plot training results
# You can do this after running the trainer. You don't need this unless you know what you're doing.
# The first cell below may fail to load all your logs. Keep trying the second cell until all data has loaded.

# %%
# %load_ext tensorboard
# %tensorboard --logdir={log_folder}/

# %%
from tensorboard import notebook
notebook.display(port=6006, height=800)
